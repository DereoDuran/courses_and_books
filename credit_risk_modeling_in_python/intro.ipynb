# %%
import numpy as np
import pandas as pd

# %%
descriptions = pd.read_excel('LCDataDictionary.xlsx')
descriptions.rename(columns={'LoanStatNew': 'name', 'Description': 'description'}, inplace=True)
descriptions.head()
# Out:
#                    name                                        description
# 0        acc_now_delinq  The number of accounts on which the borrower i...
# 1  acc_open_past_24mths         Number of trades opened in past 24 months.
# 2            addr_state  The state provided by the borrower in the loan...
# 3              all_util              Balance to credit limit on all trades
# 4            annual_inc  The self-reported annual income provided by th...

# %%
df = pd.read_csv('loan.csv')
print(df.shape)
df.head()
# Out:
# C:\Users\josec\AppData\Local\Temp\ipykernel_26152\3159766819.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')
# (2260668, 145)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
# 1     18.94       777.23     D        D2  ...                            NaN
# ...

# %%
categorical = df.select_dtypes(include=['object']).columns
numerical = df.select_dtypes(include=['int64', 'float64']).columns

print(f'Out of {df.shape[1]} columns, {len(categorical)} are categorical and {len(numerical)} are numerical.')
print(f'The categorical columns are: {", ".join(categorical)}')
print(f'The numerical columns are: {", ".join(numerical)}')
# Out:
# Out of 145 columns, 36 are categorical and 109 are numerical.
# The categorical columns are: term, grade, sub_grade, emp_title, emp_length, home_ownership, verification_status, issue_d, loan_status, pymnt_plan, desc, purpose, title, zip_code, addr_state, earliest_cr_line, initial_list_status, last_pymnt_d, next_pymnt_d, last_credit_pull_d, application_type, verification_status_joint, sec_app_earliest_cr_line, hardship_flag, hardship_type, hardship_reason, hardship_status, hardship_start_date, hardship_end_date, payment_plan_start_date, hardship_loan_status, disbursement_method, debt_settlement_flag, debt_settlement_flag_date, settlement_status, settlement_date
# ...

# %%
df['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    748005
# 2 years      203677
# < 1 year     189988
# 3 years      180753
# 1 year       148403
# 5 years      139698
# 4 years      136605
# 6 years      102628
# 7 years       92695
# 8 years       91914
# 9 years       79395
# Name: count, dtype: int64

# %%
pd.get_dummies(df['emp_length'], columns=['emp_length'], prefix='emp_length')
# Out:
#          emp_length_1 year  emp_length_10+ years  emp_length_2 years  \
# 0                    False                  True               False
# 1                    False                  True               False
# 2                    False                 False               False
# 3                    False                  True               False
# 4                    False                  True               False
# ...                    ...                   ...                 ...
# 2260663              False                  True               False
# 2260664              False                 False               False
# 2260665              False                  True               False
# 2260666              False                 False               False
# 2260667              False                 False               False
#
#          emp_length_3 years  emp_length_4 years  emp_length_5 years  \
# 0                     False               False               False
# ...
