# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
descriptions = pd.read_excel('LCDataDictionary.xlsx')
descriptions.rename(columns={'LoanStatNew': 'name', 'Description': 'description'}, inplace=True)
descriptions.sample(5)
# Out:
#                                      name  \
# 127  sec_app_mths_since_last_major_derog
# 33                            installment
# 70                           num_tl_30dpd
# 24                        funded_amnt_inv
# 90                              revol_bal
#
#                                            description
# 127   Months since most recent 90-day or worse rati...
# 33   The monthly payment owed by the borrower if th...
# 70   Number of accounts currently 30 days past due ...
# 24   The total amount committed by investors for th...
# 90                      Total credit revolving balance

# %%
# download from https://www.dropbox.com/scl/fi/rzqaawjqwt4qe3rmnnxiw/loan_data_2007_2014.csv?rlkey=a5y6ojznit1ozu8fwt0m7w11w&dl=0

df = pd.read_csv('loan_data_2007_2014.csv')
print(df.shape)
df.sample(5).T
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('https://www.dropbox.com/scl/fi/rzqaawjqwt4qe3rmnnxiw/loan_data_2007_2014.csv?rlkey=a5y6ojznit1ozu8fwt0m7w11w&dl=0')
#       2 print(df.shape)
#       3 df.sample(5).T
#
# File c:\Users\josec\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\josec\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\josec\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\josec\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 3

# %%
def months_from_date(ser, reference_date = '2024-01-01', time_format='%b-%y'):
    return (
            pd.to_datetime(reference_date).year - pd.to_datetime(ser, format=time_format).dt.year
        ) * 12 + (
            pd.to_datetime(reference_date).month - pd.to_datetime(ser, format=time_format).dt.month
        ).astype('Float64')

def dummy_encode_df(df_, category_columns = [
        "grade",
        "sub_grade",
        "home_ownership",
        "verification_status",
        "loan_status",
        "purpose",
        "addr_state",
        "initial_list_status",
    ]):

    return pd.concat([df_[category_columns], pd.get_dummies(
        df_,
        columns=category_columns,
        drop_first=True
        )], axis=1)

def zfill_df(df_, columns_to_zfill = [
        "mths_since_earliest_cr_line",
        "acc_now_delinq",
        "total_acc",
        "pub_rec",
        "open_acc",
        "inq_last_6mths",
        "delinq_2yrs",
        "emp_length_int",
    ]):

    return df_.assign(**{
        k:df_.loc[:,k].fillna(0) for k in columns_to_zfill
    })

# %%
loan_data = (df
             .iloc[:,1:]
             .set_index('id')
             .assign(
                 term_num=lambda df_: df_.term.str.split(expand=True).iloc[:,0],
                 emp_length_int=lambda df_: df_
                                        .emp_length
                                        .replace({
                                            "< 1 year": "0.5", '10+ years': "11"
                                         })
                                        .str.extract(r'(\d+\.?\d*)')
                                        .astype('Float64'),
                mths_since_earliest_cr_line=lambda df_: months_from_date(df_.earliest_cr_line),
                mths_since_issue_d=lambda df_: months_from_date(df_.issue_d),
                total_rev_hi_lim=lambda df_: df_.total_rev_hi_lim.fillna(df_.funded_amnt),
                annual_inc=lambda df_: df_.annual_inc.fillna(df_.annual_inc.mean()),
                good_bad=lambda df_: np.where(df_.loan_status.isin(['Charged Off', 'Default', 'Does not meet the credit policy. Status:Charged Off', 'Late (31-120 days)']),0,1)
             )
             .query("mths_since_earliest_cr_line > 0")
             .pipe(dummy_encode_df)
             .pipe(zfill_df)
)
loan_data
# Out:
#         grade sub_grade home_ownership verification_status  loan_status  \
# id
# 1077501     B        B2           RENT            Verified   Fully Paid
# 1077430     C        C4           RENT     Source Verified  Charged Off
# 1077175     C        C5           RENT        Not Verified   Fully Paid
# 1076863     C        C1           RENT     Source Verified   Fully Paid
# 1075358     B        B5           RENT     Source Verified      Current
# ...       ...       ...            ...                 ...          ...
# 8598660     C        C2       MORTGAGE     Source Verified      Current
# 9684700     D        D5       MORTGAGE            Verified  Charged Off
# 9584776     D        D1       MORTGAGE            Verified      Current
# 9604874     A        A4            OWN            Verified   Fully Paid
# 9199665     D        D3       MORTGAGE            Verified      Current
#
#                     purpose addr_state initial_list_status  member_id  \
# id
# 1077501         credit_card         AZ                   f    1296599
# 1077430                 car         GA                   f    1314167
# 1077175      small_business         IL                   f    1313524
# 1076863               other         CA                   f    1277178
# 1075358               other         OR                   f    1311748
# ...                     ...        ...                 ...        ...
# 8598660  debt_consolidation         TX                   w    1440975
# 9684700  debt_consolidation         TN                   f   11536848
# 9584776  debt_consolidation         OH                   f   11436914
# 9604874         credit_card         CA                   w   11457002
# 9199665               other         CA                   f   11061576
#
#          loan_amnt  ...  addr_state_TN  addr_state_TX addr_state_UT  \
# id                  ...
# 1077501       5000  ...          False          False         False
# 1077430       2500  ...          False          False         False
# 1077175       2400  ...          False          False         False
# 1076863      10000  ...          False          False         False
# 1075358       3000  ...          False          False         False
# ...            ...  ...            ...            ...           ...
# 8598660      18400  ...          False           True         False
# 9684700      22000  ...           True          False         False
# 9584776      20700  ...          False          False         False
# 9604874       2000  ...          False          False         False
# 9199665      10000  ...          False          False         False
#
#          addr_state_VA  addr_state_VT addr_state_WA addr_state_WI  \
# id
# 1077501          False          False         False         False
# 1077430          False          False         False         False
# 1077175          False          False         False         False
# 1076863          False          False         False         False
# 1075358          False          False         False         False
# ...                ...            ...           ...           ...
# 8598660          False          False         False         False
# 9684700          False          False         False         False
# 9584776          False          False         False         False
# 9604874          False          False         False         False
# 9199665          False          False         False         False
#
#          addr_state_WV addr_state_WY initial_list_status_w
# id
# 1077501          False         False                 False
# 1077430          False         False                 False
# 1077175          False         False                 False
# 1076863          False         False                 False
# 1075358          False         False                 False
# ...                ...           ...                   ...
# 8598660          False         False                  True
# 9684700          False         False                 False
# 9584776          False         False                 False
# 9604874          False         False                  True
# 9199665          False         False                 False
#
# [465087 rows x 196 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    loan_data.drop('good_bad', axis=1),
    loan_data.good_bad,
    test_size=.2,
    random_state=42
    )

# %%
x_train_with_target = pd.concat([x_train, y_train], axis=1)
x_train_with_target.sample(5)
# Out:
#          grade sub_grade home_ownership verification_status  \
# id
# 1080572      C        C5           RENT        Not Verified
# 32389696     D        D1       MORTGAGE            Verified
# 7062771      B        B4           RENT            Verified
# 10170443     B        B2       MORTGAGE        Not Verified
# 3917737      C        C4            OWN            Verified
#
#                 loan_status             purpose addr_state  \
# id
# 1080572          Fully Paid  debt_consolidation         MO
# 32389696  Late (16-30 days)  debt_consolidation         NC
# 7062771             Current  debt_consolidation         CA
# 10170443            Current  debt_consolidation         DC
# 3917737         Charged Off  debt_consolidation         VA
#
#          initial_list_status  member_id  loan_amnt  ...  addr_state_TX  \
# id                                                  ...
# 1080572                    f    1317288       2200  ...          False
# 32389696                   w   35002989      12000  ...          False
# 7062771                    f    8724349      24000  ...          False
# 10170443                   f   12021974       7000  ...          False
# 3917737                    w    5010975      11100  ...          False
#
#           addr_state_UT addr_state_VA  addr_state_VT  addr_state_WA  \
# id
# 1080572           False         False          False          False
# 32389696          False         False          False          False
# 7062771           False         False          False          False
# 10170443          False         False          False          False
# 3917737           False          True          False          False
#
#          addr_state_WI addr_state_WV  addr_state_WY initial_list_status_w  \
# id
# 1080572          False         False          False                 False
# 32389696         False         False          False                  True
# 7062771          False         False          False                 False
# 10170443         False         False          False                 False
# 3917737          False         False          False                  True
#
#          good_bad
# id
# 1080572         1
# 32389696        1
# 7062771         1
# 10170443        1
# 3917737         0
#
# [5 rows x 196 columns]

# %%
feature = 'grade'
target = 'good_bad'

woe_metrics = (x_train_with_target.groupby(feature, observed=True)[target]
 .agg(prop_good='mean',n_obs='count')
 .assign(
     prop_n_obs=lambda df_: df_.n_obs.div(df_.n_obs.sum()),
     n_good=lambda df_: df_.prop_good * df_.n_obs,
     n_bad=lambda df_: (1-df_.prop_good) * df_.n_obs,
     prop_n_good=lambda df_: df_.n_good.div(df_.n_good.sum()),
     prop_n_bad=lambda df_: df_.n_bad.div(df_.n_bad.sum()),
     WoE=lambda df_: np.log(df_.prop_n_good.div(df_.prop_n_bad)))
 .sort_values(by='WoE', ascending=False)
)

print((woe_metrics.prop_n_good - woe_metrics.prop_n_bad).mul(woe_metrics.WoE).sum())

woe_metrics
# Out:
# 0.2958816109036884
#        prop_good   n_obs  prop_n_obs    n_good    n_bad  prop_n_good  \
# grade
# A       0.961505   59592    0.160164   57298.0   2294.0     0.172951
# B       0.921852  109126    0.293295  100598.0   8528.0     0.303650
# C       0.885029   99956    0.268649   88464.0  11492.0     0.267024
# D       0.844769   61489    0.165262   51944.0   9545.0     0.156790
# E       0.805162   28634    0.076959   23055.0   5579.0     0.069590
# F       0.756800   10588    0.028457    8013.0   2575.0     0.024187
# G       0.716841    2684    0.007214    1924.0    760.0     0.005807
#
#        prop_n_bad       WoE
# grade
# A        0.056263  1.122977
# B        0.209158  0.372785
# C        0.281853 -0.054048
# D        0.234101 -0.400843
# E        0.136831 -0.676119
# F        0.063155 -0.959776
# G        0.018640 -1.166149
